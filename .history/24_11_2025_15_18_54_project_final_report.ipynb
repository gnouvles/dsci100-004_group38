# %% [markdown]
# <h1>DSCI100-004 Group 38 Final Report</h1>

# %%
library(tidyverse)
library(repr)
library(tidymodels)
library(GGally)
library(ISLR)
options(repr.matrix.max.rows = 6)
source("cleanup.R")

# %%
url <- "https://docs.google.com/spreadsheets/d/e/2PACX-1vSSCemak0WawdLW14cASkemh8MmSgoFKf2FOZy-ypDcxcbvtyqG8vZih_rWViQnfkGN8Fuh4iqj4ag8/pub?gid=988986282&single=true&output=csv"
players <- read_csv(url)

# %% [markdown]
# <h2>Introduction</h2>

# %% [markdown]
# Can age and experience level predict the total amount of gameplay hours a player contributes on the MineCraft server?

# %% [markdown]
# <h2>Methods & Results</h2>

# %% [markdown]
# <h2>Discussion</h2>
